# %%
import numpy as np
import pandas as pd
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
import matplotlib.pyplot as plt

# %%
#Function 4

#Load the input and output data for function 1
inputs = np.load('initial_data/function_4/initial_inputs.npy')
outputs = np.load('initial_data/function_4/initial_outputs.npy')

input_data = pd.DataFrame(inputs, columns = ['Input 1', ' Input 2', 'Input 3','Input 4'])
output_data = pd.DataFrame(outputs, columns = ['Output'])
data = input_data.join(output_data)
data
# Out:
#      Input 1   Input 2   Input 3   Input 4     Output
# 0   0.896981  0.725628  0.175404  0.701694 -22.108288
# 1   0.889356  0.499588  0.539269  0.508783 -14.601397
# 2   0.250946  0.033693  0.145380  0.494932 -11.699932
# 3   0.346962  0.006250  0.760564  0.613024 -16.053765
# 4   0.124871  0.129770  0.384400  0.287076 -10.069633
# 5   0.801303  0.500231  0.706645  0.195103 -15.487083
# 6   0.247708  0.060445  0.042186  0.441324 -12.681685
# 7   0.746702  0.757092  0.369353  0.206566 -16.026400
# 8   0.400665  0.072574  0.886768  0.243842 -17.049235
# 9   0.626071  0.586751  0.438806  0.778858 -12.741766
# 10  0.957135  0.597644  0.766114  0.776210 -27.316396
# 11  0.732812  0.145250  0.476813  0.133366 -13.527649
# 12  0.655115  0.072392  0.687152  0.081517 -16.679115
# 13  0.219734  0.832031  0.482864  0.082569 -16.507159
# 14  0.488594  0.211965  0.939178  0.376192 -17.817999
# 15  0.167130  0.876555  0.217240  0.959801 -26.561821
# ...

# %%
kernel = C(1.0, constant_value_bounds="fixed") * RBF(length_scale = 0.1, length_scale_bounds="fixed")

gp = GaussianProcessRegressor(
    kernel=kernel,
    alpha=1e-10,
    normalize_y = True)

gp.fit(inputs, outputs)
# Out:
# GaussianProcessRegressor(kernel=1**2 * RBF(length_scale=0.1), normalize_y=True)

# %%
#Initialize the grid
grid_size = 50
x1 = np.linspace(0, 1, grid_size)
x2 = np.linspace(0, 1, grid_size)
x3 = np.linspace(0, 1, grid_size)
x4 = np.linspace(0, 1, grid_size)
X1g, X2g, X3g, X4g = np.meshgrid(x1, x2, x3, x4)
#Write the grid as a list of candidate points
grid = np.column_stack([X1g.ravel(), X2g.ravel(), X3g.ravel(),X4g.ravel()])


# GP predictions
mu, std = gp.predict(grid, return_std=True)

beta = 1.96   # UCB exploration parameter
UCB = mu + beta * std

# %%
best_idx = np.argmax(UCB)
x_next = grid[best_idx]
x_next
# Out:
# array([0.48979592, 0.44897959, 0.44897959, 0.20408163])
