# %%
import numpy as np
import pandas as pd
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
import matplotlib.pyplot as plt

# %%
#Function 5

#Load the input and output data for function 1
inputs = np.load('initial_data/function_5/initial_inputs.npy')
outputs = np.load('initial_data/function_5/initial_outputs.npy')

input_data = pd.DataFrame(inputs, columns = ['Input 1', ' Input 2', 'Input 3','Input 4'])
output_data = pd.DataFrame(outputs, columns = ['Output'])
data = input_data.join(output_data)
data
# Out:
#      Input 1   Input 2   Input 3   Input 4       Output
# 0   0.191447  0.038193  0.607418  0.414584    64.443440
# 1   0.758653  0.536518  0.656000  0.360342    18.301380
# 2   0.438350  0.804340  0.210245  0.151295     0.112940
# 3   0.706051  0.534192  0.264243  0.482088     4.210898
# 4   0.836478  0.193610  0.663893  0.785649   258.370525
# 5   0.683432  0.118663  0.829046  0.567577    78.434389
# 6   0.553621  0.667350  0.323806  0.814870    57.571537
# 7   0.352356  0.322242  0.116979  0.473113   109.571876
# 8   0.153786  0.729382  0.422598  0.443074     8.847992
# 9   0.463442  0.630025  0.107906  0.957644   233.223610
# 10  0.677491  0.358510  0.479592  0.072880    24.423088
# 11  0.583973  0.147243  0.348097  0.428615    64.420147
# 12  0.306889  0.316878  0.622634  0.095399    63.476716
# 13  0.511142  0.817957  0.728710  0.112354    79.729130
# 14  0.438933  0.774092  0.378167  0.933696   355.806818
# 15  0.224189  0.846480  0.879484  0.878516  1088.859618
# ...

# %%
kernel = C(1.0, constant_value_bounds="fixed") * RBF(length_scale = 0.1, length_scale_bounds="fixed")

gp = GaussianProcessRegressor(
    kernel=kernel,
    alpha=1e-10,
    normalize_y = True)

gp.fit(inputs, outputs)
# Out:
# GaussianProcessRegressor(kernel=1**2 * RBF(length_scale=0.1), normalize_y=True)

# %%
#Initialize the grid
grid_size = 50
x1 = np.linspace(0, 1, grid_size)
x2 = np.linspace(0, 1, grid_size)
x3 = np.linspace(0, 1, grid_size)
x4 = np.linspace(0, 1, grid_size)
X1g, X2g, X3g, X4g = np.meshgrid(x1, x2, x3, x4)
#Write the grid out in a list for the acquisition function to evaluate on
grid = np.column_stack([X1g.ravel(), X2g.ravel(), X3g.ravel(),X4g.ravel()])


# GP predictions
mu, std = gp.predict(grid, return_std=True)

beta = 1.96   # UCB exploration parameter
UCB = mu + beta * std

# %%
best_idx = np.argmax(UCB)
x_next = grid[best_idx]
x_next
# Out:
# array([0.20408163, 0.85714286, 0.83673469, 0.85714286])
