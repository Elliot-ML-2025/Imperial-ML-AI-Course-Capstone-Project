# %%
import numpy as np
import pandas as pd
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
import matplotlib.pyplot as plt

# %%
#Function 2
inputs = np.load('initial_data/function_2/initial_inputs.npy')
outputs = np.load('initial_data/function_2/initial_outputs.npy')

input_data = pd.DataFrame(inputs, columns = ['Input 1', ' Input 2'])
output_data = pd.DataFrame(outputs, columns = ['Output'])
data = input_data.join(output_data2)
data
# Out:
#     Input 1   Input 2    Output
# 0  0.665800  0.123969  0.538996
# 1  0.877791  0.778628  0.420586
# 2  0.142699  0.349005 -0.065624
# 3  0.845275  0.711120  0.293993
# 4  0.454647  0.290455  0.214965
# 5  0.577713  0.771973  0.023106
# 6  0.438166  0.685018  0.244619
# 7  0.341750  0.028698  0.038749
# 8  0.338648  0.213867 -0.013858
# 9  0.702637  0.926564  0.611205

# %%
kernel = C(1.0, constant_value_bounds="fixed") * RBF(length_scale= 0.1, length_scale_bounds="fixed")

gp = GaussianProcessRegressor(
    kernel=kernel,
    alpha=1e-10,
    normalize_y=True
)

gp.fit(inputs, outputs)
# Out:
# GaussianProcessRegressor(kernel=1**2 * RBF(length_scale=0.1), normalize_y=True)

# %%
#Initialize grid for predictions 
grid_size = 1000
x1 = np.linspace(0, 1, grid_size)
x2 = np.linspace(0, 1, grid_size)
X1g, X2g = np.meshgrid(x1, x2)
#Write the points out in a list to be evaluated
grid = np.column_stack([X1g.ravel(), X2g.ravel()])

# GP predictions
mu, std = gp.predict(grid, return_std=True)

beta = 1.96   # UCB exploration parameter
UCB = mu + beta * std

# %%
best_idx = np.argmax(UCB)
x_next = grid[best_idx]
x_next
# Out:
# array([0.7997998 , 0.91991992])
