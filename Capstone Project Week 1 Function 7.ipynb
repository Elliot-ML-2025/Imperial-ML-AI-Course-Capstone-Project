# %%
import numpy as np
import pandas as pd
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

# %%
#Function 7

#Load the input and output data for function 1
inputs = np.load('initial_data/function_7/initial_inputs.npy')
outputs = np.load('initial_data/function_7/initial_outputs.npy')

input_data = pd.DataFrame(inputs, columns = ['Input 1', ' Input 2', 'Input 3','Input 4',
                                             'Input 5','Input 6'])
output_data = pd.DataFrame(outputs, columns = ['Output'])
data = input_data.join(output_data)
data
# Out:
#      Input 1   Input 2   Input 3   Input 4   Input 5   Input 6    Output
# 0   0.272624  0.324495  0.897109  0.832951  0.154063  0.795864  0.604433
# 1   0.543003  0.924694  0.341567  0.646486  0.718440  0.343133  0.562753
# 2   0.090832  0.661529  0.065931  0.258577  0.963453  0.640265  0.007503
# 3   0.118867  0.615055  0.905816  0.855300  0.413631  0.585236  0.061424
# 4   0.630218  0.838097  0.680013  0.731895  0.526737  0.348429  0.273047
# 5   0.764919  0.255883  0.609084  0.218079  0.322943  0.095794  0.083747
# 6   0.057896  0.491672  0.247422  0.218118  0.420428  0.730970  1.364968
# 7   0.195252  0.079227  0.554580  0.170567  0.014944  0.107032  0.092645
# 8   0.642303  0.836875  0.021793  0.101488  0.683071  0.692416  0.017870
# 9   0.789943  0.195545  0.575623  0.073659  0.259049  0.051100  0.033565
# 10  0.528497  0.457424  0.360096  0.362046  0.816891  0.637476  0.073516
# 11  0.722615  0.011813  0.063646  0.165173  0.079244  0.359952  0.206310
# ...

# %%
kernel = C(1.0, constant_value_bounds="fixed") * RBF(length_scale = 0.1, length_scale_bounds="fixed")

gp = GaussianProcessRegressor(
    kernel=kernel,
    alpha=1e-10,
    normalize_y = True)

gp.fit(inputs, outputs)
# Out:
# GaussianProcessRegressor(kernel=1**2 * RBF(length_scale=0.1), normalize_y=True)

# %%
#Initialize the grid
grid_size = 12
x1 = np.linspace(0, 1, grid_size)
x2 = np.linspace(0, 1, grid_size)
x3 = np.linspace(0, 1, grid_size)
x4 = np.linspace(0, 1, grid_size)
x5 = np.linspace(0, 1, grid_size)
x6 = np.linspace(0, 1, grid_size)
X1g, X2g, X3g, X4g, X5g, X6g = np.meshgrid(x1, x2, x3, x4, x5,x6)
#Write the grid out in a list for the acquisition function to evaluate on
grid = np.column_stack([X1g.ravel(), X2g.ravel(), X3g.ravel(),X4g.ravel(), X5g.ravel(),
                       X6g.ravel()])


# GP predictions
mu, std = gp.predict(grid, return_std=True)

beta = 0.2   # UCB exploration parameter
UCB = mu + beta * std

# %%
best_idx = np.argmax(UCB)
x_next = grid[best_idx]
x_next
# Out:
# array([0.09090909, 0.45454545, 0.27272727, 0.18181818, 0.45454545,
#        0.72727273])

# %%
# Out:
# 1.3649683044991994
